# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Read csv file
df = pd.read_csv("mldata(2).csv")

# %%
#Plot weight and height
sns.scatterplot(x ='weight', y = 'height', data=df)

# %%
#Plot age and height
sns.scatterplot(x ='age', y = 'height', data=df)

# %%
#Pick age weight and height to store in cm
cm = df[["age",'weight','height']]

# %%
#Assign age and weigt to x as input
X = df[['age', 'weight']]
y = df['height']

# %%
#import test train libraires
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
#import liner regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train=np.arange(0,len(X_train),1)

# %%
y_test=np.arange(0,len(y_test),1)

# %%
import matplotlib.pyplot as plt 
plt.scatter(X_train, y_train, color ='red')
plt.xlabel("Age and weight")
plt.ylabel("height")
plt.show()

# Visualize the test set results
plt.scatter(X_test, y_test, color ='red')
plt.xlabel("Age and weight")
plt.ylabel("height")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-2e52b687ae25> in <module>
#       6
#       7 # Visualize the test set results
# ----> 8 plt.scatter(X_test, y_test, color ='red')
#       9 plt.xlabel("Age and weight")
#      10 plt.ylabel("height")
#
# ~\Anaconda3\envs\machine-learning\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# ~\Anaconda3\envs\machine-learning\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...
